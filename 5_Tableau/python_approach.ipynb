# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# 1. Load the dataset into a notebook.

# %%
data = pd.read_csv('./files_for_lab/we_fn_use_c_marketing_customer_value_analysis.csv')
display(data.shape)
data.head(1)
# Out:
# (9134, 24)
#   Customer       State  Customer Lifetime Value Response Coverage Education  \
# 0  BU79786  Washington              2763.519279       No    Basic  Bachelor
#
#   Effective To Date EmploymentStatus Gender  Income  ...  \
# 0           2/24/11         Employed      F   56274  ...
#
#   Months Since Policy Inception Number of Open Complaints  Number of Policies  \
# 0                             5                         0                   1
#
#       Policy Type        Policy  Renew Offer Type  Sales Channel  \
# 0  Corporate Auto  Corporate L3            Offer1          Agent
#
#   Total Claim Amount Vehicle Class Vehicle Size
# 0         384.811147  Two-Door Car      Medsize
#
# [1 rows x 24 columns]

# %% [markdown]
# 2. Create a barplot of the number of customers per Gender.

# %%
gender_counts = data['Gender'].value_counts()
sns.barplot(x=gender_counts.index, y=gender_counts.values)
# Out:
# <Axes: xlabel='Gender'>

# %% [markdown]
# 3. Create a barplot of the number of customers per EmploymentStatus and Gender.

# %%
e_g_data = data.pivot_table(index= ['Gender','EmploymentStatus'], values = ['Customer'], aggfunc = {'Customer':'count'}).reset_index()
sns.barplot(x='EmploymentStatus', y='Customer', hue='Gender', data=e_g_data)
# Out:
# <Axes: xlabel='EmploymentStatus', ylabel='Customer'>

# %% [markdown]
# 4. Identify Measurements and Dimensions. Are they the same as both ones in your Pandas dataframe? Modify accordingly.

# %%
def identify_dimensions_and_measures(data):
    dimensions = []
    measures = []
    for column in data.columns:
        if data[column].dtype == 'object':
            # If the data type is object (string) --> dimension
            dimensions.append(column)
        elif data[column].dtype in ['int64', 'float64']:
            # If the data type is int64 or float64 -->  measure
            measures.append(column)
    
    return dimensions, measures

dimensions, measures = identify_dimensions_and_measures(data)
print("Dimensions:", dimensions)
print("Measures:", measures)
# Out:
# Dimensions: ['Customer', 'State', 'Response', 'Coverage', 'Education', 'Effective To Date', 'EmploymentStatus', 'Gender', 'Location Code', 'Marital Status', 'Policy Type', 'Policy', 'Renew Offer Type', 'Sales Channel', 'Vehicle Class', 'Vehicle Size']
# Measures: ['Customer Lifetime Value', 'Income', 'Monthly Premium Auto', 'Months Since Last Claim', 'Months Since Policy Inception', 'Number of Open Complaints', 'Number of Policies', 'Total Claim Amount']

# %% [markdown]
# 5. Save as unit-4-lab.tbwx.

# %% [markdown]
# - not applicable, this is not a tableau workbook
